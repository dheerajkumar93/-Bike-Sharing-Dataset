# %% [markdown]
# # Data Reading

# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Mounting colab with google drive to access the csv from there
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reading the training dataset

bike_data_train = pd.read_csv("/content/drive/MyDrive/Projects/Bike_Sharing/train.csv")

# %%
# Reading the test dataset

bike_data_test = pd.read_csv("/content/drive/MyDrive/Projects/Bike_Sharing/test.csv")

# %% [markdown]
# # EDA

# %%
# Reading head - training data

bike_data_train.head()
# Out:
#               datetime  season  holiday  ...  casual  registered  count
# 0  2011-01-01 00:00:00       1        0  ...       3          13     16
# 1  2011-01-01 01:00:00       1        0  ...       8          32     40
# 2  2011-01-01 02:00:00       1        0  ...       5          27     32
# 3  2011-01-01 03:00:00       1        0  ...       3          10     13
# 4  2011-01-01 04:00:00       1        0  ...       0           1      1
#
# [5 rows x 12 columns]

# %%
# Reading head - test data

bike_data_test.head()
# Out:
#               datetime  season  holiday  ...   atemp  humidity  windspeed
# 0  2011-01-20 00:00:00       1        0  ...  11.365        56    26.0027
# 1  2011-01-20 01:00:00       1        0  ...  13.635        56     0.0000
# 2  2011-01-20 02:00:00       1        0  ...  13.635        56     0.0000
# 3  2011-01-20 03:00:00       1        0  ...  12.880        56    11.0014
# 4  2011-01-20 04:00:00       1        0  ...  12.880        56    11.0014
#
# [5 rows x 9 columns]

# %%
# Checking number of rows and columns - traning dataset

bike_data_train.shape
# Out:
# (10886, 12)

# %%
# Checking number of rows and columns - test dataset

bike_data_test.shape
# Out:
# (6493, 9)

# %%
# Checking datatypes - traning dataset

bike_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
# Checking datatypes - test dataset

bike_data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    6493 non-null   object
#  1   season      6493 non-null   int64
#  2   holiday     6493 non-null   int64
#  3   workingday  6493 non-null   int64
#  4   weather     6493 non-null   int64
#  5   temp        6493 non-null   float64
#  6   atemp       6493 non-null   float64
#  7   humidity    6493 non-null   int64
#  8   windspeed   6493 non-null   float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 456.7+ KB

# %%
# Checking null values - training dataset

bike_data_train.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
# Checking null values - test dataset

bike_data_test.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# dtype: int64

# %%
# Checking unique values - test dataset

bike_data_train.nunique()
# Out:
# datetime      10886
# season            4
# holiday           2
# workingday        2
# weather           4
# temp             49
# atemp            60
# humidity         89
# windspeed        28
# casual          309
# registered      731
# count           822
# dtype: int64

# %%
# Checking unique values - training datasets

bike_data_test.nunique()
# Out:
# datetime      6493
# season           4
# holiday          2
# workingday       2
# weather          4
# temp            49
# atemp           65
# humidity        79
# windspeed       27
# dtype: int64

# %%
# Analysing distribution of target variable - counts

fig=plt.figure(figsize=(10,6))
sns.distplot(bike_data_train['count'])
plt.title("Bike sharing data distribution")
# Out:
# Text(0.5, 1.0, 'Bike sharing data distribution')

# %%
# Checking distribution of all features - traning dataset

bike_data_train.hist(figsize=(30,30), color = 'skyblue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f676b2cf5d0>,
# ...
#       dtype=object)

# %%
# Plotting relation between 'holiday' and 'total_bikes_rented'

plt.figure(figsize=(12,8))
sns.regplot(data=bike_data_train, x = bike_data_train['holiday'], y= bike_data_train['total_bikes_rented'], line_kws={"color": "red"})

# %%
# Plotting relation between 'weather' and 'total_bikes_rented'

plt.figure(figsize=(12,8))
sns.regplot(data=bike_data_train, x = bike_data_train['weather'], y= bike_data_train['total_bikes_rented'], line_kws={"color": "red"})

# %%
# Plotting relation between 'temp' and 'total_bikes_rented'

plt.figure(figsize=(12,8))
sns.regplot(data=bike_data_train, x = bike_data_train['temp'], y= bike_data_train['total_bikes_rented'], line_kws={"color": "red"})

# %%
# Plotting relation between 'atemp' and 'total_bikes_rented'

plt.figure(figsize=(12,8))
sns.regplot(data=bike_data_train, x = bike_data_train['atemp'], y= bike_data_train['total_bikes_rented'] ,line_kws={"color": "red"})

# %%
# Plotting relation between 'humidity' and 'total_bikes_rented'

plt.figure(figsize=(12,8))
sns.regplot(data=bike_data_train, x = bike_data_train['humidity'], y= bike_data_train['total_bikes_rented'], line_kws={"color": "red"})

# %%
# Plotting relation between 'windspeed' and 'total_bikes_rented'

plt.figure(figsize=(12,8))
sns.regplot(data=bike_data_train, x = bike_data_train['windspeed'], y= bike_data_train['total_bikes_rented'], line_kws={"color": "red"})

# %%
# Checking distribution of all features - test dataset

bike_data_train.hist(figsize=(30,30), color = 'green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f676939ec90>,
# ...
#       dtype=object)

# %%
# Checking unique values in each column - training dataset

for col in bike_data_train:
    print(col)
    print("\n")
    print(bike_data_train[col].unique())
    print("\n\n")
# Out:
# datetime
#
#
# ['2011-01-01 00:00:00' '2011-01-01 01:00:00' '2011-01-01 02:00:00' ...
#  '2012-12-19 21:00:00' '2012-12-19 22:00:00' '2012-12-19 23:00:00']
#
#
#
# season
#
#
# [1 2 3 4]
#
#
#
# holiday
#
#
# [0 1]
#
#
#
# workingday
#
#
# [0 1]
#
#
#
# weather
#
#
# [1 2 3 4]
#
#
#
# temp
#
#
# [ 9.84  9.02  8.2  13.12 15.58 14.76 17.22 18.86 18.04 16.4  13.94 12.3
#  10.66  6.56  5.74  7.38  4.92 11.48  4.1   3.28  2.46 21.32 22.96 23.78
#  24.6  19.68 22.14 20.5  27.06 26.24 25.42 27.88 28.7  30.34 31.16 29.52
#  33.62 35.26 36.9  32.8  31.98 34.44 36.08 37.72 38.54  1.64  0.82 39.36
#  41.  ]
#
#
#
# atemp
#
#
# [14.395 13.635 12.88  17.425 19.695 16.665 21.21  22.725 21.97  20.455
#  11.365 10.605  9.85   8.335  6.82   5.305  6.06   9.09  12.12   7.575
#  15.91   3.03   3.79   4.545 15.15  18.18  25.    26.515 27.275 29.545
#  23.485 25.76  31.06  30.305 24.24  18.94  31.82  32.575 33.335 28.79
#  34.85  35.605 37.12  40.15  41.665 40.91  39.395 34.09  28.03  36.365
# ...

# %%
# Checking unique values in each column - test dataset

for col in bike_data_test:
    print(col)
    print("\n")
    print(bike_data_test[col].unique())
    print("\n\n")
# Out:
# datetime
#
#
# ['2011-01-20 00:00:00' '2011-01-20 01:00:00' '2011-01-20 02:00:00' ...
#  '2012-12-31 21:00:00' '2012-12-31 22:00:00' '2012-12-31 23:00:00']
#
#
#
# season
#
#
# [1 2 3 4]
#
#
#
# holiday
#
#
# [0 1]
#
#
#
# workingday
#
#
# [1 0]
#
#
#
# weather
#
#
# [1 2 3 4]
#
#
#
# temp
#
#
# [10.66  9.84  9.02 11.48 12.3  13.12  8.2   6.56  5.74  4.92  4.1   3.28
#   2.46  1.64  0.82  7.38 13.94 14.76 17.22 15.58 16.4  21.32 22.14 22.96
#  18.86 18.04 19.68 20.5  23.78 25.42 27.06 28.7  30.34 31.16 27.88 24.6
#  26.24 29.52 31.98 33.62 32.8  35.26 36.08 36.9  34.44 37.72 38.54 39.36
#  40.18]
#
#
#
# atemp
#
#
# [11.365 13.635 12.88  10.605 16.665 14.395 15.15  15.91  12.12   9.85
#   9.09   8.335  7.575  6.06   6.82   5.305  3.79   1.515  2.275  0.
#   0.76   3.03   4.545 17.425 18.18  21.21  19.695 20.455 25.    25.76
#  26.515 22.725 21.97  23.485 24.24  27.275 30.305 31.06  32.575 33.335
#  31.82  29.545 28.79  28.03  34.09  34.85  37.12  38.635 37.88  36.365
# ...

# %%
# Checking duplicate rows in data - training dataset

bike_data_train[bike_data_train.duplicated()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, casual, registered, count]
# Index: []

# %%
# Checking duplicate rows in data - test dataset

bike_data_test[bike_data_test.duplicated()]
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed]
# Index: []

# %% [markdown]
# # Data Cleaning

# %%
# Renaming 'count' column in training dataset for better readability

bike_data_train.rename(columns = {'count':'total_bikes_rented'}, inplace = True)

# %%
# checking head to see if column name is replaced

bike_data_train.head()
# Out:
#               datetime  season  holiday  ...  casual  registered  total_bikes_rented
# 0  2011-01-01 00:00:00       1        0  ...       3          13                  16
# 1  2011-01-01 01:00:00       1        0  ...       8          32                  40
# 2  2011-01-01 02:00:00       1        0  ...       5          27                  32
# 3  2011-01-01 03:00:00       1        0  ...       3          10                  13
# 4  2011-01-01 04:00:00       1        0  ...       0           1                   1
#
# [5 rows x 12 columns]

# %%
# Renaming 'count' column in test dataset for better readability

bike_data_test.rename(columns = {'count':'total_bikes_rented'}, inplace = True)

# %%
# checking head to see if column name is replaced

bike_data_test.head()
# Out:
#               datetime  season  holiday  ...   atemp  humidity  windspeed
# 0  2011-01-20 00:00:00       1        0  ...  11.365        56    26.0027
# 1  2011-01-20 01:00:00       1        0  ...  13.635        56     0.0000
# 2  2011-01-20 02:00:00       1        0  ...  13.635        56     0.0000
# 3  2011-01-20 03:00:00       1        0  ...  12.880        56    11.0014
# 4  2011-01-20 04:00:00       1        0  ...  12.880        56    11.0014
#
# [5 rows x 9 columns]

# %%
# converting column 'datetime' datatype to datetime - Training dataset

bike_data_train['datetime'] = bike_data_train['datetime'].apply(pd.to_datetime)

# %%
# converting column 'datetime' datatype to datetime - Test dataset

bike_data_test['datetime'] = bike_data_test['datetime'].apply(pd.to_datetime)

# %%
# checking info of 'datetime' column

bike_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     10886 non-null  datetime64[ns]
#  1   season       10886 non-null  int64
#  2   holiday      10886 non-null  int64
#  3   workingday   10886 non-null  int64
#  4   weather      10886 non-null  int64
#  5   temp         10886 non-null  float64
#  6   atemp        10886 non-null  float64
#  7   humidity     10886 non-null  int64
#  8   windspeed    10886 non-null  float64
#  9   casual       10886 non-null  int64
#  10  registered   10886 non-null  int64
#  11  count        10886 non-null  int64
#  12  time_hour    10886 non-null  int64
#  13  day_of_week  10886 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(9), object(1)
# memory usage: 1.2+ MB

# %%
# extracting day from 'datetime' column in training dataset

import datetime
bike_data_train['time_hour'] = bike_data_train['datetime'].dt.hour

# %%
# Checking newly created column 'time_hour'

bike_data_train['time_hour'].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: time_hour, dtype: int64

# %%
# Checking distribution of 'time_hour' vs 'total_bikes_rented'

plt.figure(figsize=(15,10))
import seaborn as sns
sns.boxplot(bike_data_train['time_hour'],bike_data_train['total_bikes_rented'])

# %%
# extracting day from 'datetime' column in test dataset

import datetime
bike_data_test['time_hour'] = bike_data_test['datetime'].dt.hour

# %%
# Creating column 'day_of_week' to check day - Training dataset

bike_data_train['day_of_week'] = bike_data_train['datetime'].dt.day_name()

# %%
# Checking newly created column 'day_of_week'

bike_data_train['day_of_week'].head()
# Out:
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# 4    Saturday
# Name: day_of_week, dtype: object

# %%
# Creating column 'day_of_week' to check day - Test dataset

bike_data_test['day_of_week'] = bike_data_test['datetime'].dt.day_name()

# %%
# Checking value counts for each value in 'day_of_week' column

bike_data_train['day_of_week'].value_counts()
# Out:
# Saturday     1584
# Sunday       1579
# Thursday     1553
# Wednesday    1551
# Monday       1551
# Tuesday      1539
# Friday       1529
# Name: day_of_week, dtype: int64

# %%
# Converting 'day_of_week' column to category codes - Training dataset

bike_data_train['day_of_week'] = bike_data_train['day_of_week'].astype('category')
bike_data_train['day_of_week'] = bike_data_train['day_of_week'].cat.codes

# %%
# Checking value counts for each value in 'day_of_week' column

bike_data_train['day_of_week'].value_counts()
# Out:
# 2    1584
# 3    1579
# 4    1553
# 6    1551
# 1    1551
# 5    1539
# 0    1529
# Name: day_of_week, dtype: int64

# %%
# Converting 'day_of_week' column to category codes - Test dataset

bike_data_test['day_of_week'] = bike_data_test['day_of_week'].astype('category')
bike_data_test['day_of_week'] = bike_data_test['day_of_week'].cat.codes

# %%
# Checking distribution of 'day_of_week' vs 'total_bikes_rented'

plt.figure(figsize=(15,10))
import seaborn as sns
sns.boxplot(bike_data_train['day_of_week'],bike_data_train['total_bikes_rented'])

# %% [markdown]
# # Feature engineering

# %%
# Getting correlation between features

corr = bike_data_train.corr()

f, ax = plt.subplots(figsize=(15, 15))

# Plotting heat map

sns.heatmap(corr, annot=True)

# Displaying plot

plt.show()

# %%
# Creating bins of 4-hour interval in Training dataset

hour_bins = [-1,4,8,12,16,20,23]
hour_bin_labels = [1,2,3,4,5,6]
bike_data_train['hours_binned']=pd.cut(bike_data_train['time_hour'],bins=hour_bins,labels=hour_bin_labels)

# %%
# Checking distribution of 'hours_binned' vs 'total_bikes_rented'

plt.figure(figsize=(15,10))
import seaborn as sns
sns.boxplot(bike_data_train['hours_binned'],bike_data_train['total_bikes_rented'])

# %%
# Creating bins of 4-hour interval in Test dataset

hour_bins = [-1,4,8,12,16,20,23]
hour_bin_labels = [1,2,3,4,5,6]
bike_data_test['hours_binned']=pd.cut(bike_data_test['time_hour'],bins=hour_bins,labels=hour_bin_labels)

# %%
# Dropping column 'datetime' from training dataset

bike_data_train.drop('datetime', axis=1, inplace=True)

# %%
# Dropping column 'datetime' from test dataset

bike_data_test.drop('datetime', axis=1, inplace=True)

# %%
# Dropping column 'casual' and 'registered' from training dataset

bike_data_train.drop(columns = ['casual', 'registered',], axis=1, inplace=True)

# %%
# Dropping column 'time_hour' from training dataset

bike_data_train.drop('time_hour', axis=1, inplace=True)

# %%
# Dropping column 'time_hour' from test dataset

bike_data_test.drop('time_hour', axis=1, inplace=True)

# %% [markdown]
# # Model Preparation

# %%
# Checking head of final dataset - Training dataset

bike_data_train.head()
# Out:
#    season  holiday  workingday  ...  total_bikes_rented  day_of_week  hours_binned
# 0       1        0           0  ...                  16            2             1
# 1       1        0           0  ...                  40            2             1
# 2       1        0           0  ...                  32            2             1
# 3       1        0           0  ...                  13            2             1
# 4       1        0           0  ...                   1            2             1
#
# [5 rows x 11 columns]

# %%
# Checking head of final dataset - Training dataset

bike_data_test.head()
# Out:
#    season  holiday  workingday  ...  windspeed  day_of_week  hours_binned
# 0       1        0           1  ...    26.0027            4             1
# 1       1        0           1  ...     0.0000            4             1
# 2       1        0           1  ...     0.0000            4             1
# 3       1        0           1  ...    11.0014            4             1
# 4       1        0           1  ...    11.0014            4             1
#
# [5 rows x 10 columns]

# %%
# Splitting data into training and test

# Select Features
feature = bike_data_train.drop('total_bikes_rented', axis=1)

# Select Target
target = bike_data_train['total_bikes_rented']

# Set Training and Testing Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(feature , target, 
                                                    shuffle = True, 
                                                    test_size=0.3, 
                                                    random_state=0)

# Show the Training and Testing Data
print('Shape of training feature:', X_train.shape)
print('Shape of testing feature:', X_test.shape)
print('Shape of training label:', y_train.shape)
print('Shape of training label:', y_test.shape)
# Out:
# Shape of training feature: (7620, 10)
# Shape of testing feature: (3266, 10)
# Shape of training label: (7620,)
# Shape of training label: (3266,)

# %%
from sklearn.ensemble import RandomForestRegressor

# RandomForest Regression model

rf = RandomForestRegressor(random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
# Predicting results - on training dataset

y_pred_train = rf.predict(X_train)
y_pred_train
# Out:
# array([267.8       , 787.24      , 163.84      , ..., 591.70216667,
#        226.33266667, 386.38      ])

# %%
# Predicting results

y_pred_test = rf.predict(X_test)
y_pred_test
# Out:
# array([135.25      , 270.69666667, 155.51      , ..., 137.57833333,
#        123.28      , 115.14      ])

# %% [markdown]
# # Model Evaluation

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

def cross_val(model):
    pred = cross_val_score(model, X, y, cv=10)
    return pred.mean()

def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('Mean Absolute error(MAE) is:', mae)
    print('Mean squared Error(MSE) is:', mse)
    print('Root Mean Squared error(RMSE) is:', rmse)
    print('R2 Square is:', r2_square)

# %%
# Printing train and test results metrics

print('Test set evaluation:\n_____________________________________________________\n')
print_evaluate(y_test, y_pred_test)
print('\nTrain set evaluation:\n_____________________________________________________\n')
print_evaluate(y_train, y_pred_train)
# Out:
# Test set evaluation:
# _____________________________________________________
#
# Mean Absolute error(MAE) is: 70.13413030168273
# Mean squared Error(MSE) is: 11410.308770741809
# Root Mean Squared error(RMSE) is: 106.81904685374144
# R2 Square is: 0.648641939455301
#
# Train set evaluation:
# _____________________________________________________
#
# Mean Absolute error(MAE) is: 26.480809784998467
# Mean squared Error(MSE) is: 1702.8009699120387
# Root Mean Squared error(RMSE) is: 41.26500902595368
# R2 Square is: 0.9483202102025036

# %%
# Predicting results on final test dataset

y_pred_test_final = rf.predict(bike_data_test)
y_pred_test
# Out:
# array([135.25      , 270.69666667, 155.51      , ..., 137.57833333,
#        123.28      , 115.14      ])
